# %%
# Magic function
# To generate matplotlib within the matplotlib browser, pass inline as backend
# %matplotlib inline


# Less is more effective
# Less is more attactive
# Less is more impactive

# import matplotlib

# Matplotlib notebook backend is used to add labels, title to the
# plot without re-rendering the plot.
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.ylabel('Y')
plt.xlabel('X')
plt.title('Plotting Example')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Plotting Example')

# %%
#2 Matpllotlib with Pandas

india_china_df.plot(kind='line')

# For plotting histogram for India column
india_china_df.plot(kind='hist')

# %%
# Immigration dataset
